# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy as sp
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
diab_data = pd.read_csv('diabetes.csv')
diab_data.head(15)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
print('# of patients in original data: ' + str(len(diab_data.index)))
# Out:
# # of patients in original data: 768

# %%
print(diab_data.head(len(diab_data.index)))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
plt.figure(figsize=(20,10))
diab_pos = sns.countplot(x="Age", hue="Outcome", data=diab_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
diab_data["Insulin"].plot.hist(bins=20,figsize=(10,5))

# %%
diab_data.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
diab_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.heatmap(diab_data.isnull(), yticklabels = False)

# %%
pd.get_dummies(diab_data["Age"]>30)
# Out:
#      False  True
# 0        0      1
# 1        0      1
# 2        0      1
# 3        1      0
# 4        0      1
# ..     ...    ...
# 763      0      1
# 764      1      0
# 765      1      0
# 766      0      1
# 767      1      0
#
# [768 rows x 2 columns]

# %%
diab_pos = sns.countplot(x="Pregnancies", hue="Outcome", data=diab_data)

# %%
plt.figure(figsize=(50,30))
diab_1 = sns.countplot(x="Glucose", hue="Outcome", data=diab_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(50,20))
diab_1 = sns.countplot(x="BMI", hue="Outcome", data=diab_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(50,20))
diab_1 = sns.countplot(x="DiabetesPedigreeFunction", hue="Outcome", data=diab_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
